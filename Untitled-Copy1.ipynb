# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df= pd.read_excel('data.xlsx')
df
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20      45
# 3     25       5

# %%
df.plot.scatter(x="metro" , y="precio")
plt.show()

# %%
lineal= linear_model.LinearRegression()

# %%
metros = df["metro"].values.reshape((-1,1))

# %%
modelo= lineal.fit(metros,df["precio"])

print("Intersección (b)", modelo.intercept_)
#Se imprime la pendiente 
print("Pendiente (m)", modelo.coef_)
# Out:
# Intersección (b) 570.8285714285714
# Pendiente (m) [-21.09714286]

# %%
df.plot.scatter(x="metro" , y="precio")
plt.scatter(entrada,predicciones, color ='red')
plt.plot(entrada,predicciones,color = 'black' , label = 'Linea de Regresión')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 df.plot.scatter(x="metro" , y="precio")
# ----> 2 plt.scatter(entrada,predicciones, color ='red')
#       3 plt.plot(entrada,predicciones,color = 'black' , label = 'Linea de Regresión')
#       4 plt.xlabel('metro')
#
# NameError: name 'entrada' is not defined

# %%
entrada= [[5],[15],[20],[25]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [465.34285714 254.37142857 148.88571429  43.4       ]
